# %% [markdown]
# # Análisis 2da Encuesta de inserción de científicos en Chile
#
# **Autor:** Roberto Muñoz <br />
# **E-mail:** <rmunoz@metricarts.com> <br />
# **Github:** <https://github.com/rpmunoz> <br />
#
# Análisis preliminar de la [2da Encuesta de inserción de científicos](https://www.anip.cl/encuesta-insercion-2018) llevada a cabo por el Centro de estudios de la ANIP.

# %%
import os
import shutil
import numpy as np
import pandas as pd
from scipy import stats, integrate

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
from IPython.core.display import display, HTML

# %matplotlib inline
params = {'legend.fontsize': 'large',
          'figure.figsize': (8, 6),
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large',
         'axes.titlepad': 16,
         'axes.titlesize': 20,
         'axes.labelpad': 16,
         'axes.labelsize': 16,
         'lines.linewidth': 3,
         'lines.markersize': 8,
         'xtick.labelsize': 12,
         'ytick.labelsize': 12}
plt.rcParams.update(params)

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Cargamos el archivo de datos original
#
# Cargamos el archivos de datos que contiene todas las encuestas válidas.

# %%
encuesta_full_file="../encuesta/E2018-full-answers.csv"

encuesta_full_df=pd.read_csv(encuesta_full_file)
encuesta_full_df.head()
# Out:
#    ID de la respuesta  Fecha en que inició Fecha de la ultima accion  \
# 0                  41  2018-01-19 12:21:56       2018-01-19 13:02:59
# 1                  42  2018-01-19 12:24:06       2018-01-19 12:29:59
# 2                  43  2018-01-19 12:26:32       2018-01-19 12:34:04
# 3                  44  2018-01-19 12:28:30       2018-01-19 12:36:47
# 4                  45  2018-01-19 12:37:03       2018-01-19 12:44:43
#
#   ¿Cuál es el grado académico más alto que has obtenido?  \
# 0                                    Doctorado (PhD)
# 1                                    Doctorado (PhD)
# 2                                     Magíster (MSc)
# 3                                    Doctorado (PhD)
# 4                                    Doctorado (PhD)
#
#   ¿En qué disciplina y área clasificarías tu pregrado?  \
# 0             Ciencias Naturales:Ciencias Biológicas
# 1                  Humanidades:Lenguaje y Literatura
# 2         Ciencias Sociales:Ciencias de la Educación
# 3               Ciencias Naturales:Ciencias Químicas
# 4                     Ciencias Naturales:Matemáticas
#
#   ¿En qué disciplina y área clasificarías tu pregrado? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿En qué año obtuviste tu pregrado?  \
# 0                               2003
# 1                               2004
# 2                               2014
# 3                               2012
# 4                               2010
#
#   ¿En qué disciplina y área clasificarías tu {postgrado}?  \
# 0             Ciencias Naturales:Ciencias Biológicas
# 1                  Humanidades:Lenguaje y Literatura
# 2  Ciencias Médicas y de la Salud:Ciencias de la ...
# 3               Ciencias Naturales:Ciencias Químicas
# 4                     Ciencias Naturales:Matemáticas
#
#   ¿En qué disciplina y área clasificarías tu {postgrado}? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿En qué año obtuviste tu {postgrado}?  \
# 0                                  2017
# 1                                  2017
# 2                                  2018
# 3                                  2016
# 4                                  2017
#
#   ¿En qué lugar realizaste tu {postgrado}?  \
# 0                                    Chile
# 1                                   España
# 2                                    Chile
# 3                                    Chile
# 4                                  Francia
#
#    En total, ¿cuántos artículos revisados por pares (peer-reviewed) has publicado en los últimos 5 años?  \
# 0                                                 10
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  1
#
#   ¿Cómo financiaste tus estudios de {postgrado}? [Fondos personales (e.g., ahorros, aporte familiar, etc.)]  \
# 0                                                 No
# 1                                                 No
# 2                                                 Sí
# 3                                                 No
# 4                                                 No
#
#   ¿Cómo financiaste tus estudios de {postgrado}? [Trabajo durante el estudio (e.g., pasantías, ayudantías, etc.)]  \
# 0                                                 Sí
# 1                                                 No
# 2                                                 Sí
# 3                                                 No
# 4                                                 No
#
#   ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales nacionales (e.g., becas Conicyt, Becas Chile, premios, etc.)]  \
# 0                                                 Sí
# 1                                                 Sí
# 2                                                 No
# 3                                                 Sí
# 4                                                 Sí
#
#   ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales extranjeros (e.g., becas o premios de universidad de estudios)]  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en mi área de estudio]  \
# 0                                                 No
# 1                                                NaN
# 2                                                 Sí
# 3                                                NaN
# 4                                                NaN
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en otra área de estudio]  \
# 0                                                 No
# 1                                                NaN
# 2                                                 Sí
# 3                                                NaN
# 4                                                NaN
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Pasantía(s) en otros lugares de estudio o centros de investigación]  \
# 0                                                 No
# 1                                                NaN
# 2                                                 Sí
# 3                                                NaN
# 4                                                NaN
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo en mi lugar de estudio, sin relación con mis estudios]  \
# 0                                                 No
# 1                                                NaN
# 2                                                 Sí
# 3                                                NaN
# 4                                                NaN
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo fuera de mi lugar de estudio]  \
# 0                                                 Sí
# 1                                                NaN
# 2                                                 No
# 3                                                NaN
# 4                                                NaN
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo remoto de cualquier tipo]  \
# 0                                                 No
# 1                                                NaN
# 2                                                 Sí
# 3                                                NaN
# 4                                                NaN
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)]  \
# 0                                                 Sí
# 1                                                 Sí
# 2                                                NaN
# 3                                                 Sí
# 4                                                 Sí
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario]  \
# 0                                  Doctorado CONICYT
# 1                                       Becas chile
# 2                                                NaN
# 3                                            CONICYT
# 4                                        Becas Chile
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)]  \
# 0                                                 No
# 1                                                 No
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)]  \
# 0                                                 No
# 1                                                 No
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)]  \
# 0                                                 No
# 1                                                 No
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Estás realizando o has realizado algún postdoctorado?  \
# 0                                                 No
# 1                                                 No
# 2                                                NaN
# 3                                                 Sí
# 4                                                 No
#
#   ¿En qué disciplina y área clasificarías tu postdoctorado?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3       Ingeniería y Tecnología:Ingeniería Ambiental
# 4                                                NaN
#
#   ¿En qué disciplina y área clasificarías tu postdoctorado? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿En qué año terminaste tu postdoctorado? Si actuamente estás haciendo un postdoctorado, por favor responde "Estoy haciendo un postdoctorado ahora".  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3              Estoy haciendo un postdoctorado ahora
# 4                                                NaN
#
#   ¿En qué lugar realizaste (o estás realizando) tu postdoctorado?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              Chile
# 4                                                NaN
#
#   ¿Has terminado más de un postdoctorado?  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                      No
# 4                                     NaN
#
#   ¿Cuántos postdoctorados has realizado?  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                     ¿Estás en Chile ahora?  \
# 0                                      NaN
# 1  Sí, estoy en Chile de manera definitiva
# 2                                      NaN
# 3                                      NaN
# 4  Sí, estoy en Chile de manera definitiva
#
#   ¿Tuviste que renunciar a algún trabajo u oportunidad académica por volver a Chile?  \
# 0                                                NaN
# 1                                                 Sí
# 2                                                NaN
# 3                                                NaN
# 4                                                 No
#
#   Por favor describe brevemente el trabajo u oportunidad académica que perdiste por volver a Chile:  \
# 0                                                NaN
# 1    Querían que me quedara a un proyecto en la UGR
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Hace cuánto tiempo volviste a Chile?  \
# 0                                   NaN
# 1                      Entre 1 y 2 años
# 2                                   NaN
# 3                                   NaN
# 4                   Entre 10 y 12 meses
#
#   Luego de volver a Chile, ¿cuánto tiempo te tomó encontrar tu primer trabajo?  \
# 0                                                NaN
# 1                                No encontré trabajo
# 2                                                NaN
# 3                                                NaN
# 4                                  Entre 7 y 9 meses
#
#   ¿Qué tan relacionado estaba ese trabajo con tu especialización en el {postgrado}?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                               1 (Nada relacionado)
#
#   En general, ¿cómo calificarías tu experiencia de reinserción en Chile?  \
# 0                                                NaN
# 1                                       1 (muy mala)
# 2                                                NaN
# 3                                                NaN
# 4                                                  2
#
#   ¿Por qué razón(es) no volverás a Chile? [Porque nunca encontré trabajo relacionado con mis estudios]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Por qué razón(es) no volverás a Chile? [Porque en Chile no pude desarrollar mi área de investigación]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Por qué razón(es) no volverás a Chile? [Porque recibí una muy buena oferta de trabajo en el extranjero]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Por qué razón(es) no volverás a Chile? [Por motivos personales/familiares]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Por qué razón(es) no volverás a Chile? [Otro]  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   ¿Por qué razón tienes que volver a Chile? [Porque firmé un pagaré que me obliga a volver]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Por qué razón tienes que volver a Chile? [Porque tengo un acuerdo con mi empleador]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Por qué razón tienes que volver a Chile? [Otro]  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   ¿Tu trabajo o búsqueda de trabajo está centrado en el el ámbito de la investigación científica?  \
# 0                                                 Sí
# 1                                                 Sí
# 2                                                 Sí
# 3                                                 Sí
# 4                                                 No
#
#   Actualmente, ¿tienes trabajo remunerado en Chile?  \
# 0                                                Sí
# 1                                                No
# 2                                                No
# 3                                                Sí
# 4                                                Sí
#
#   ¿Cuántos trabajos posees actualmente?  \
# 0                                     1
# 1                                   NaN
# 2                                   NaN
# 3                                     1
# 4                                     1
#
#    {if(G5Q00003.NAOK=="1", "", "Para las preguntas siguientes, considera sólo el trabajo al que dedicas mayor cantidad de tiempo.")}  ¿Cuántas horas a la semana, en promedio, dedicas a este trabajo?  \
# 0                                               44.0
# 1                                                NaN
# 2                                                NaN
# 3                                               40.0
# 4                                               45.0
#
#   ¿En qué institución o área realizas tu trabajo?  \
# 0                 Universidad pública/tradicional
# 1                                             NaN
# 2                                             NaN
# 3                 Universidad pública/tradicional
# 4                              Sector Empresarial
#
#   ¿En qué institución o área realizas tu trabajo? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     ¿A qué sector económico pertenece este trabajo?  \
# 0                             Sector Primario:Pesca
# 1                                               NaN
# 2                                               NaN
# 3       Sector Cuaternario:Investigación científica
# 4  Sector Cuaternario:Tecnologías de la información
#
#   ¿A qué sector económico pertenece este trabajo? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿En qué región de Chile realizas este trabajo?  \
# 0                                 X de los Lagos
# 1                                            NaN
# 2                                            NaN
# 3                               VIII del Bío Bío
# 4                 XIII Metropolitana de Santiago
#
#   ¿Qué tan relacionado está tu trabajo con tu especialización en el {postgrado}?  \
# 0                      7 (Completamente relacionado)
# 1                                                NaN
# 2                                                NaN
# 3                                                  6
# 4                               1 (Nada relacionado)
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu salario]  \
# 0                                                  5
# 1                                                NaN
# 2                                                NaN
# 3                                                  6
# 4                                                  3
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Los beneficios que te ofrece el trabajo]  \
# 0                                                  5
# 1                                                NaN
# 2                                                NaN
# 3                                                  2
# 4                                                  2
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu estabilidad laboral]  \
# 0                                                  6
# 1                                                NaN
# 2                                                NaN
# 3                                                  2
# 4                                 7 (Muy satisfecho)
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [La localización del trabajo]  \
# 0                                                  6
# 1                                                NaN
# 2                                                NaN
# 3                                 7 (Muy satisfecho)
# 4                                 7 (Muy satisfecho)
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Las condiciones generales de trabajo]  \
# 0                                                  6
# 1                                                NaN
# 2                                                NaN
# 3                                                  2
# 4                                                  6
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [La posibilidad de progreso]  \
# 0                                 7 (Muy satisfecho)
# 1                                                NaN
# 2                                                NaN
# 3                                                  2
# 4                                                  5
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [El reto intelectual que supone el trabajo]  \
# 0                                                  6
# 1                                                NaN
# 2                                                NaN
# 3                                 7 (Muy satisfecho)
# 4                  4 (Ni satisfecho ni insatisfecho)
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [El nivel de responsabilidad que tienes en el trabajo]  \
# 0                                                  6
# 1                                                NaN
# 2                                                NaN
# 3                                                  5
# 4                  4 (Ni satisfecho ni insatisfecho)
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu grado de independencia en el trabajo]  \
# 0                                                  6
# 1                                                NaN
# 2                                                NaN
# 3                                                  6
# 4                                                  6
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu contribución a la sociedad a través del trabajo]  \
# 0                                 7 (Muy satisfecho)
# 1                                                NaN
# 2                                                NaN
# 3                                 7 (Muy satisfecho)
# 4                  4 (Ni satisfecho ni insatisfecho)
#
#   ¿Qué tan necesario es tener un {postgrado} para realizar este trabajo?  \
# 0                        7 (Completamente necesario)
# 1                                                NaN
# 2                                                NaN
# 3                                                  6
# 4                      1 (Completamente innecesario)
#
#   ¿En qué grado este trabajo pone en riesgo tu...? [Integridad Física]  \
# 0                                 1 (Nada de riesgo)
# 1                                                NaN
# 2                                                NaN
# 3                                 1 (Nada de riesgo)
# 4                                                  2
#
#   ¿En qué grado este trabajo pone en riesgo tu...? [Integridad Psicológica]  \
# 0                                                  5
# 1                                                NaN
# 2                                                NaN
# 3                                 1 (Nada de riesgo)
# 4                                                  2
#
#   ¿En qué grado este trabajo pone en riesgo tu...? [Salud en general]  \
# 0                             4 (En riesgo moderado)
# 1                                                NaN
# 2                                                NaN
# 3                                 1 (Nada de riesgo)
# 4                                                  2
#
#   ¿En qué grado este trabajo pone en riesgo tu...? [Seguridad personal o familiar]  \
# 0                                 1 (Nada de riesgo)
# 1                                                NaN
# 2                                                NaN
# 3                                 1 (Nada de riesgo)
# 4                                                  2
#
#   ¿Cuentas con un seguro o previsión de salud?  \
# 0                                           Sí
# 1                                          NaN
# 2                                          NaN
# 3                                           Sí
# 4                                           Sí
#
#   ¿En qué grado tu seguro o previsión de salud cubre los riesgos que implica tu trabajo?  \
# 0                                                  5
# 1                                                NaN
# 2                                                NaN
# 3                 1 (No cubre para nada los riesgos)
# 4                 4 (Cubre parcialmente los riesgos)
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Académico/docencia]  \
# 0                                                 Sí
# 1                                                NaN
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Administrativo/Gestión]  \
# 0                                                 No
# 1                                                NaN
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Asistente de investigación]  \
# 0                                                 No
# 1                                                NaN
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Consultoría]  \
# 0                                                 No
# 1                                                NaN
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Director de proyectos]  \
# 0                                                 No
# 1                                                NaN
# ...
# 0                                                 No
# 1                                                NaN
# 2                                                NaN
# 3                                                 No
# 4                                                 No
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                        Programador
#
#   ¿Qué tipo de relación laboral tienes en este trabajo?  \
# 0                            Contrato con plazo fijo
# 1                                                NaN
# 2                                                NaN
# 3                               Contrato a honorario
# 4                                Contrato indefinido
#
#   ¿Qué tipo de relación laboral tienes en este trabajo? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Considerando todos tus ingresos, ¿en que rango sitúas tu ingreso líquido mensual total?  \
# 0                        Entre 1.200.001 y 2.000.000
# 1                                                NaN
# 2                                                NaN
# 3                          Entre 700.001 y 1.200.000
# 4                          Entre 700.001 y 1.200.000
#
#   ¿Qué tan satisfecho estás con tu nivel de ingresos total mensual?  \
# 0                  4 (Ni satisfecho ni insatisfecho)
# 1                                                NaN
# 2                                                NaN
# 3                                                  5
# 4                                                  2
#
#   ¿Crees que deberías tener más tiempo para investigar en este trabajo?  \
# 0                                                 Sí
# 1                                                NaN
# 2                                                NaN
# 3                                                 No
# 4                                                 Sí
#
#   ¿Cuántas horas a la semana, en promedio, debería aumentar tu dedicación a la investigación?  \
# 0                                                  8
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                 25
#
#   ¿Crees que deberías tener más tiempo para enseñar en este trabajo?  \
# 0                                                 No
# 1                                                NaN
# 2                                                NaN
# 3                                                 Sí
# 4                                                 No
#
#   ¿Cuántas horas a la semana, en promedio, debería aumentar tu dedicación a la docencia?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                  6
# 4                                                NaN
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [No he sufrido discriminación]  \
# 0                                                 Sí
# 1                                                NaN
# 2                                                NaN
# 3                                                 Sí
# 4                                                NaN
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación de género]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por ser extranjero/a]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por tener discapacidad]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por tener hijos o hijas]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por estar sobrecalificado]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Otro]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Actualmente, ¿estás buscando trabajo?  \
# 0                                   NaN
# 1                                    Sí
# 2                                    Sí
# 3                                   NaN
# 4                                   NaN
#
#    ¿Hace cuántos meses estás buscando trabajo?  \
# 0                                          NaN
# 1                                         12.0
# 2                                          5.0
# 3                                          NaN
# 4                                          NaN
#
#   ¿Crees que seguirás desempeñando este trabajo remunerado en julio de 2018?  \
# 0                                                 Sí
# 1                                                NaN
# 2                                                NaN
# 3                                 No estoy seguro(a)
# 4                                                 Sí
#
#   Finalmente, ¿cuál es tu opinión sobre el sistema de ciencia y tecnología en Chile, y sobre el proceso de inserción de científicos en Chile?  \
# 0  Los fondos de financiamiento público de CyT ac...
# 1  Pésimo.  Soy la única doctora en Chilenconó mi...
# 2  No existe el sistema. Lo que existe es la volu...
# 3  El proceso de inserción es muy deficiente cons...
# 4                                                NaN
#
#   ¿Cuál es tu género? ¿Cuál es tu edad?  \
# 0           Masculino                40
# 1            Femenino                37
# 2           Masculino                36
# 3           Masculino                31
# 4           Masculino                31
#
#   ¿Cuál es tu nacionalidad? En caso de tener más de una nacionalidad, por favor escoge tu país de origen (donde naciste).  \
# 0                                              Chile
# 1                                              Chile
# 2                                              Chile
# 3                                              Chile
# 4                                              Chile
#
#   Durante tu formación profesional, ¿ha sido uno de tus anhelos trabajar en el ámbito académico?  \
# 0                                                 Sí
# 1                                                 Sí
# 2                                                 Sí
# 3                                                 Sí
# 4                                                 Sí
#
#   Tiempo total  Tiempo del grupo: Sección 1: Preguntas iniciales  \
# 0      2462.84                                             23.55
# 1        354.3                                             20.29
# 2       452.28                                             21.43
# 3       498.22                                             24.70
# 4       460.37                                             11.80
#
#    Tiempo del grupo: Sección 2: Sobre situación académica  \
# 0                                             197.77
# 1                                             124.67
# 2                                             118.88
# 3                                             114.68
# 4                                              78.39
#
#    Tiempo del grupo: Sección 3: Sobre la realización de postdoctorados  \
# 0                                              13.71
# 1                                              10.15
# 2                                                NaN
# 3                                              43.02
# 4                                              13.97
#
#    Tiempo del grupo: Sección 4: Sobre reinserción en Chile  \
# 0                                                NaN
# 1                                              56.66
# 2                                                NaN
# 3                                                NaN
# 4                                              58.91
#
#    Tiempo del grupo: Sección 5: Sobre situación laboral  \
# 0                                             340.90
# 1                                              24.43
# 2                                              30.19
# 3                                             191.56
# 4                                             248.88
#
#    Tiempo del grupo: Sección 6: Preguntas finales  Unnamed: 131
# 0                                         1886.91           NaN
# 1                                          118.10           NaN
# 2                                          281.78           NaN
# 3                                          124.26           NaN
# 4                                           48.42           NaN

# %%
n_registros=len(encuesta_full_df)
print("Numbero de registros", n_registros)
# Out:
# Numbero de registros 752

# %%
n_campos=len(list(encuesta_full_df.keys()))
print("Numbero de campos", n_campos)
# Out:
# Numbero de campos 132

# %%
encuesta_full_df.dtypes.to_frame().transpose()
# Out:
#   ID de la respuesta Fecha en que inició Fecha de la ultima accion  \
# 0              int64              object                    object
#
#   ¿Cuál es el grado académico más alto que has obtenido?  \
# 0                                             object
#
#   ¿En qué disciplina y área clasificarías tu pregrado?  \
# 0                                             object
#
#   ¿En qué disciplina y área clasificarías tu pregrado? [Otro]  \
# 0                                             object
#
#   ¿En qué año obtuviste tu pregrado?  \
# 0                             object
#
#   ¿En qué disciplina y área clasificarías tu {postgrado}?  \
# 0                                             object
#
#   ¿En qué disciplina y área clasificarías tu {postgrado}? [Otro]  \
# 0                                             object
#
#   ¿En qué año obtuviste tu {postgrado}?  \
# 0                                object
#
#   ¿En qué lugar realizaste tu {postgrado}?  \
# 0                                   object
#
#   En total, ¿cuántos artículos revisados por pares (peer-reviewed) has publicado en los últimos 5 años?  \
# 0                                              int64
#
#   ¿Cómo financiaste tus estudios de {postgrado}? [Fondos personales (e.g., ahorros, aporte familiar, etc.)]  \
# 0                                             object
#
#   ¿Cómo financiaste tus estudios de {postgrado}? [Trabajo durante el estudio (e.g., pasantías, ayudantías, etc.)]  \
# 0                                             object
#
#   ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales nacionales (e.g., becas Conicyt, Becas Chile, premios, etc.)]  \
# 0                                             object
#
#   ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales extranjeros (e.g., becas o premios de universidad de estudios)]  \
# 0                                             object
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en mi área de estudio]  \
# 0                                             object
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en otra área de estudio]  \
# 0                                             object
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Pasantía(s) en otros lugares de estudio o centros de investigación]  \
# 0                                             object
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo en mi lugar de estudio, sin relación con mis estudios]  \
# 0                                             object
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo fuera de mi lugar de estudio]  \
# 0                                             object
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo remoto de cualquier tipo]  \
# 0                                             object
#
#   ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Otro]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].1  \
# 0                                             object
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].2  \
# 0                                             object
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].3  \
# 0                                             object
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].1  \
# 0                                             object
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].2  \
# 0                                             object
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)]  \
# 0                                             object
#
#   ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].3  \
# 0                                             object
#
#   ¿Estás realizando o has realizado algún postdoctorado?  \
# 0                                             object
#
#   ¿En qué disciplina y área clasificarías tu postdoctorado?  \
# 0                                             object
#
#   ¿En qué disciplina y área clasificarías tu postdoctorado? [Otro]  \
# 0                                             object
#
#   ¿En qué año terminaste tu postdoctorado? Si actuamente estás haciendo un postdoctorado, por favor responde "Estoy haciendo un postdoctorado ahora".  \
# 0                                             object
#
#   ¿En qué lugar realizaste (o estás realizando) tu postdoctorado?  \
# 0                                             object
#
#   ¿Has terminado más de un postdoctorado?  \
# 0                                  object
#
#   ¿Cuántos postdoctorados has realizado? ¿Estás en Chile ahora?  \
# 0                                 object                 object
#
#   ¿Tuviste que renunciar a algún trabajo u oportunidad académica por volver a Chile?  \
# 0                                             object
#
#   Por favor describe brevemente el trabajo u oportunidad académica que perdiste por volver a Chile:  \
# 0                                             object
#
#   ¿Hace cuánto tiempo volviste a Chile?  \
# 0                                object
#
#   Luego de volver a Chile, ¿cuánto tiempo te tomó encontrar tu primer trabajo?  \
# 0                                             object
#
#   ¿Qué tan relacionado estaba ese trabajo con tu especialización en el {postgrado}?  \
# 0                                             object
#
#   En general, ¿cómo calificarías tu experiencia de reinserción en Chile?  \
# 0                                             object
#
#   ¿Por qué razón(es) no volverás a Chile? [Porque nunca encontré trabajo relacionado con mis estudios]  \
# 0                                             object
#
#   ¿Por qué razón(es) no volverás a Chile? [Porque en Chile no pude desarrollar mi área de investigación]  \
# 0                                             object
#
#   ¿Por qué razón(es) no volverás a Chile? [Porque recibí una muy buena oferta de trabajo en el extranjero]  \
# 0                                             object
#
#   ¿Por qué razón(es) no volverás a Chile? [Por motivos personales/familiares]  \
# 0                                             object
#
#   ¿Por qué razón(es) no volverás a Chile? [Otro]  \
# 0                                         object
#
#   ¿Por qué razón tienes que volver a Chile? [Porque firmé un pagaré que me obliga a volver]  \
# 0                                             object
#
#   ¿Por qué razón tienes que volver a Chile? [Porque tengo un acuerdo con mi empleador]  \
# 0                                             object
#
#   ¿Por qué razón tienes que volver a Chile? [Otro]  \
# 0                                           object
#
#   ¿Tu trabajo o búsqueda de trabajo está centrado en el el ámbito de la investigación científica?  \
# 0                                             object
#
#   Actualmente, ¿tienes trabajo remunerado en Chile?  \
# 0                                            object
#
#   ¿Cuántos trabajos posees actualmente?  \
# 0                                object
#
#   {if(G5Q00003.NAOK=="1", "", "Para las preguntas siguientes, considera sólo el trabajo al que dedicas mayor cantidad de tiempo.")}  ¿Cuántas horas a la semana, en promedio, dedicas a este trabajo?  \
# 0                                            float64
#
#   ¿En qué institución o área realizas tu trabajo?  \
# 0                                          object
#
#   ¿En qué institución o área realizas tu trabajo? [Otro]  \
# 0                                             object
#
#   ¿A qué sector económico pertenece este trabajo?  \
# 0                                          object
#
#   ¿A qué sector económico pertenece este trabajo? [Otro]  \
# 0                                             object
#
#   ¿En qué región de Chile realizas este trabajo?  \
# 0                                         object
#
#   ¿Qué tan relacionado está tu trabajo con tu especialización en el {postgrado}?  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu salario]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Los beneficios que te ofrece el trabajo]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu estabilidad laboral]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [La localización del trabajo]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Las condiciones generales de trabajo]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [La posibilidad de progreso]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [El reto intelectual que supone el trabajo]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [El nivel de responsabilidad que tienes en el trabajo]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu grado de independencia en el trabajo]  \
# 0                                             object
#
#   Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu contribución a la sociedad a través del trabajo]  \
# 0                                             object
#
#   ¿Qué tan necesario es tener un {postgrado} para realizar este trabajo?  \
# 0                                             object
#
#   ¿En qué grado este trabajo pone en riesgo tu...? [Integridad Física]  \
# 0                                             object
#
#   ¿En qué grado este trabajo pone en riesgo tu...? [Integridad Psicológica]  \
# 0                                             object
#
#   ¿En qué grado este trabajo pone en riesgo tu...? [Salud en general]  \
# 0                                             object
#
#   ¿En qué grado este trabajo pone en riesgo tu...? [Seguridad personal o familiar]  \
# 0                                             object
#
#   ¿Cuentas con un seguro o previsión de salud?  \
# 0                                       object
#
#   ¿En qué grado tu seguro o previsión de salud cubre los riesgos que implica tu trabajo?  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Académico/docencia]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Administrativo/Gestión]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Asistente de investigación]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Consultoría]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Director de proyectos]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Docencia (ayudantía)]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Edición de textos/publicaciones]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador asociado]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador colaborador en proyectos de terceros]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador principal]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Trabajo de campo /producción de información o datos para investigación / trabajo de escritorio.]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Traducciones]  \
# 0                                             object
#
#   ¿Qué tipo de actividades desempeñas en este trabajo? [Otro]  \
# 0                                             object
#
#   ¿Qué tipo de relación laboral tienes en este trabajo?  \
# 0                                             object
#
#   ¿Qué tipo de relación laboral tienes en este trabajo? [Otro]  \
# 0                                             object
#
#   Considerando todos tus ingresos, ¿en que rango sitúas tu ingreso líquido mensual total?  \
# 0                                             object
#
#   ¿Qué tan satisfecho estás con tu nivel de ingresos total mensual?  \
# 0                                             object
#
#   ¿Crees que deberías tener más tiempo para investigar en este trabajo?  \
# 0                                             object
#
#   ¿Cuántas horas a la semana, en promedio, debería aumentar tu dedicación a la investigación?  \
# 0                                             object
#
#   ¿Crees que deberías tener más tiempo para enseñar en este trabajo?  \
# 0                                             object
#
#   ¿Cuántas horas a la semana, en promedio, debería aumentar tu dedicación a la docencia?  \
# 0                                             object
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [No he sufrido discriminación]  \
# 0                                             object
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación de género]  \
# 0                                             object
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por ser extranjero/a]  \
# 0                                             object
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por tener discapacidad]  \
# 0                                             object
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por tener hijos o hijas]  \
# 0                                             object
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por estar sobrecalificado]  \
# 0                                             object
#
#   ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Otro]  \
# 0                                             object
#
#   Actualmente, ¿estás buscando trabajo?  \
# 0                                object
#
#   ¿Hace cuántos meses estás buscando trabajo?  \
# 0                                     float64
#
#   ¿Crees que seguirás desempeñando este trabajo remunerado en julio de 2018?  \
# 0                                             object
#
#   Finalmente, ¿cuál es tu opinión sobre el sistema de ciencia y tecnología en Chile, y sobre el proceso de inserción de científicos en Chile?  \
# 0                                             object
#
#   ¿Cuál es tu género? ¿Cuál es tu edad?  \
# 0              object            object
#
#   ¿Cuál es tu nacionalidad? En caso de tener más de una nacionalidad, por favor escoge tu país de origen (donde naciste).  \
# 0                                             object
#
#   Durante tu formación profesional, ¿ha sido uno de tus anhelos trabajar en el ámbito académico?  \
# 0                                             object
#
#   Tiempo total Tiempo del grupo: Sección 1: Preguntas iniciales  \
# 0       object                                          float64
#
#   Tiempo del grupo: Sección 2: Sobre situación académica  \
# 0                                            float64
#
#   Tiempo del grupo: Sección 3: Sobre la realización de postdoctorados  \
# 0                                            float64
#
#   Tiempo del grupo: Sección 4: Sobre reinserción en Chile  \
# 0                                            float64
#
#   Tiempo del grupo: Sección 5: Sobre situación laboral  \
# 0                                            float64
#
#   Tiempo del grupo: Sección 6: Preguntas finales Unnamed: 131
# 0                                        float64      float64

# %% [markdown]
# ## 2. Análisis exploratorio y limipieza de datos
#
# Haremos un análisis exploratorio de los datos. Nos concetraremos en los últimos campos de la encuesta para revisar errores de arrastre o tipeo.

# %%
field_names_full=['¿Cuál es tu género?',
             '¿Cuál es tu edad?',
             '¿Cuál es tu nacionalidad? En caso de tener más de una nacionalidad, por favor escoge tu país de origen (donde naciste).']

# %% [markdown]
# Primero buscamos cuales de estos campos contienen valores NaN

# %%
encuesta_full_df[field_names_full].isnull().sum()
# Out:
# ¿Cuál es tu género?                                                                                                         1
# ¿Cuál es tu edad?                                                                                                          34
# ¿Cuál es tu nacionalidad? En caso de tener más de una nacionalidad, por favor escoge tu país de origen (donde naciste).     0
# dtype: int64

# %% [markdown]
# Luego buscamos los valores únicos de estos campos para encontrar posibles errores

# %%
for field_name in field_names_full:
    print(encuesta_full_df[field_name].unique())
# Out:
# ['Masculino' 'Femenino' 'Prefiero no responder'
#  ' o buscan técnicos que salen más económicos para que aprendan lo básico (y no necesariamente ir subiendo sus puestos) o buscan doctorados expertos en un área. Estando uno en un nivel intermedio (o avanzado en un área ahora sin oferta) es difícil encontrar algo.'
#  'Otro (no binario)'
#  'Creo que es muy deficiente. Faltan mecanismos para integrarse, recursos para financiar las iniciativas de inserción estatales y fomentar la participción del mundo privado. Quizás se pueda fomentar el uso de un fondo tipo Ley Valdés de donaciones, para que las empresas financien distintos tipos de investigación. '
#  nan ' con contrato y no con boleta.']
# ['40' '37' '36' '31' '32' '43' '42' '41' '34' '39' '33' '27' '29' '30' '49'
#  '38' '48' '35' nan '44' '52' '25' '45' '28' '57' 'Femenino' '50' '46' '26'
#  '61' '58' '47' 'Masculino' '68' '53']
# ['Chile' 'Francia' 'España' 'Colombia' 'Bélgica' 'Uruguay' 'Venezuela'
#  'Ecuador' 'Brasil' 'Reino Unido' 'Alemania' 'Canadá' '26' 'Argentina'
#  'Perú' '35' 'Estados Unidos de América' 'Italia' 'Cuba' 'Portugal' '38'
#  '30' 'Rusia' 'Bolivia']

# %% [markdown]
# Podemos notar que existe un existen respuestas incorrectas en los campos Genero, Edad y Nacionalidad. Explores cuales ID son las respuestas afectadas

# %% [markdown]
# Haremos una copia del archivo csv y buscaremos esos registros e

# %%
encuesta_full_file="../encuesta/E2018-full-answers.csv"
encuesta_clean_file="../encuesta/E2018-full-answers-clean.csv"

if not os.path.exists(encuesta_clean_file):
    shutil.copyfile(encuesta_full_file, encuesta_clean_file)

# %%
encuesta_full_df[encuesta_full_df['¿Cuál es tu género?']==' o buscan técnicos que salen más económicos para que aprendan lo básico (y no necesariamente ir subiendo sus puestos) o buscan doctorados expertos en un área. Estando uno en un nivel intermedio (o avanzado en un área ahora sin oferta) es difícil encontrar algo.']
# Out:
#      ID de la respuesta  Fecha en que inició Fecha de la ultima accion  \
# 197                 334  2018-01-24 23:37:08       2018-01-24 23:45:55
#
#     ¿Cuál es el grado académico más alto que has obtenido?  \
# 197                                     Magíster (MSc)
#
#     ¿En qué disciplina y área clasificarías tu pregrado?  \
# 197    Ingeniería y Tecnología:Biotecnología Ambiental
#
#     ¿En qué disciplina y área clasificarías tu pregrado? [Otro]  \
# 197                                                NaN
#
#     ¿En qué año obtuviste tu pregrado?  \
# 197                               2017
#
#     ¿En qué disciplina y área clasificarías tu {postgrado}?  \
# 197             Ingeniería y Tecnología:Nanotecnología
#
#     ¿En qué disciplina y área clasificarías tu {postgrado}? [Otro]  \
# 197                                                NaN
#
#     ¿En qué año obtuviste tu {postgrado}?  \
# 197                                  2017
#
#     ¿En qué lugar realizaste tu {postgrado}?  \
# 197                                    Chile
#
#      En total, ¿cuántos artículos revisados por pares (peer-reviewed) has publicado en los últimos 5 años?  \
# 197                                                  0
#
#     ¿Cómo financiaste tus estudios de {postgrado}? [Fondos personales (e.g., ahorros, aporte familiar, etc.)]  \
# 197                                                 Sí
#
#     ¿Cómo financiaste tus estudios de {postgrado}? [Trabajo durante el estudio (e.g., pasantías, ayudantías, etc.)]  \
# 197                                                 No
#
#     ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales nacionales (e.g., becas Conicyt, Becas Chile, premios, etc.)]  \
# 197                                                 No
#
#     ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales extranjeros (e.g., becas o premios de universidad de estudios)]  \
# 197                                                 No
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en mi área de estudio]  \
# 197                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en otra área de estudio]  \
# 197                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Pasantía(s) en otros lugares de estudio o centros de investigación]  \
# 197                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo en mi lugar de estudio, sin relación con mis estudios]  \
# 197                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo fuera de mi lugar de estudio]  \
# 197                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo remoto de cualquier tipo]  \
# 197                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Otro]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].1  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].2  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].3  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].1  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].2  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)]  \
# 197                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].3  \
# 197                                                NaN
#
#     ¿Estás realizando o has realizado algún postdoctorado?  \
# 197                                                NaN
#
#     ¿En qué disciplina y área clasificarías tu postdoctorado?  \
# 197                                                NaN
#
#     ¿En qué disciplina y área clasificarías tu postdoctorado? [Otro]  \
# 197                                                NaN
#
#     ¿En qué año terminaste tu postdoctorado? Si actuamente estás haciendo un postdoctorado, por favor responde "Estoy haciendo un postdoctorado ahora".  \
# 197                                                NaN
#
#     ¿En qué lugar realizaste (o estás realizando) tu postdoctorado?  \
# 197                                                NaN
#
#     ¿Has terminado más de un postdoctorado?  \
# 197                                     NaN
#
#     ¿Cuántos postdoctorados has realizado? ¿Estás en Chile ahora?  \
# 197                                    NaN                    NaN
#
#     ¿Tuviste que renunciar a algún trabajo u oportunidad académica por volver a Chile?  \
# 197                                                NaN
#
#     Por favor describe brevemente el trabajo u oportunidad académica que perdiste por volver a Chile:  \
# 197                                                NaN
#
#     ¿Hace cuánto tiempo volviste a Chile?  \
# 197                                   NaN
#
#     Luego de volver a Chile, ¿cuánto tiempo te tomó encontrar tu primer trabajo?  \
# 197                                                NaN
#
#     ¿Qué tan relacionado estaba ese trabajo con tu especialización en el {postgrado}?  \
# 197                                                NaN
#
#     En general, ¿cómo calificarías tu experiencia de reinserción en Chile?  \
# 197                                                NaN
#
#     ¿Por qué razón(es) no volverás a Chile? [Porque nunca encontré trabajo relacionado con mis estudios]  \
# 197                                                NaN
#
#     ¿Por qué razón(es) no volverás a Chile? [Porque en Chile no pude desarrollar mi área de investigación]  \
# 197                                                NaN
#
#     ¿Por qué razón(es) no volverás a Chile? [Porque recibí una muy buena oferta de trabajo en el extranjero]  \
# 197                                                NaN
#
#     ¿Por qué razón(es) no volverás a Chile? [Por motivos personales/familiares]  \
# 197                                                NaN
#
#     ¿Por qué razón(es) no volverás a Chile? [Otro]  \
# 197                                            NaN
#
#     ¿Por qué razón tienes que volver a Chile? [Porque firmé un pagaré que me obliga a volver]  \
# 197                                                NaN
#
#     ¿Por qué razón tienes que volver a Chile? [Porque tengo un acuerdo con mi empleador]  \
# 197                                                NaN
#
#     ¿Por qué razón tienes que volver a Chile? [Otro]  \
# 197                                              NaN
#
#     ¿Tu trabajo o búsqueda de trabajo está centrado en el el ámbito de la investigación científica?  \
# 197                                                 Sí
#
#     Actualmente, ¿tienes trabajo remunerado en Chile?  \
# 197                                                No
#
#     ¿Cuántos trabajos posees actualmente?  \
# 197                                   NaN
#
#      {if(G5Q00003.NAOK=="1", "", "Para las preguntas siguientes, considera sólo el trabajo al que dedicas mayor cantidad de tiempo.")}  ¿Cuántas horas a la semana, en promedio, dedicas a este trabajo?  \
# 197                                                NaN
#
#     ¿En qué institución o área realizas tu trabajo?  \
# 197                                             NaN
#
#     ¿En qué institución o área realizas tu trabajo? [Otro]  \
# 197                                                NaN
#
#     ¿A qué sector económico pertenece este trabajo?  \
# 197                                             NaN
#
#     ¿A qué sector económico pertenece este trabajo? [Otro]  \
# 197                                                NaN
#
#     ¿En qué región de Chile realizas este trabajo?  \
# 197                                            NaN
#
#     ¿Qué tan relacionado está tu trabajo con tu especialización en el {postgrado}?  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu salario]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Los beneficios que te ofrece el trabajo]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu estabilidad laboral]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [La localización del trabajo]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Las condiciones generales de trabajo]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [La posibilidad de progreso]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [El reto intelectual que supone el trabajo]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [El nivel de responsabilidad que tienes en el trabajo]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu grado de independencia en el trabajo]  \
# 197                                                NaN
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu contribución a la sociedad a través del trabajo]  \
# 197                                                NaN
#
#     ¿Qué tan necesario es tener un {postgrado} para realizar este trabajo?  \
# 197                                                NaN
#
#     ¿En qué grado este trabajo pone en riesgo tu...? [Integridad Física]  \
# 197                                                NaN
#
#     ¿En qué grado este trabajo pone en riesgo tu...? [Integridad Psicológica]  \
# 197                                                NaN
#
#     ¿En qué grado este trabajo pone en riesgo tu...? [Salud en general]  \
# 197                                                NaN
#
#     ¿En qué grado este trabajo pone en riesgo tu...? [Seguridad personal o familiar]  \
# 197                                                NaN
#
#     ¿Cuentas con un seguro o previsión de salud?  \
# 197                                          NaN
#
#     ¿En qué grado tu seguro o previsión de salud cubre los riesgos que implica tu trabajo?  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Académico/docencia]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Administrativo/Gestión]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Asistente de investigación]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Consultoría]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Director de proyectos]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Docencia (ayudantía)]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Edición de textos/publicaciones]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador asociado]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador colaborador en proyectos de terceros]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador principal]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Trabajo de campo /producción de información o datos para investigación / trabajo de escritorio.]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Traducciones]  \
# 197                                                NaN
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Otro]  \
# 197                                                NaN
#
#     ¿Qué tipo de relación laboral tienes en este trabajo?  \
# 197                                                NaN
#
#     ¿Qué tipo de relación laboral tienes en este trabajo? [Otro]  \
# 197                                                NaN
#
#     Considerando todos tus ingresos, ¿en que rango sitúas tu ingreso líquido mensual total?  \
# 197                                                NaN
#
#     ¿Qué tan satisfecho estás con tu nivel de ingresos total mensual?  \
# 197                                                NaN
#
#     ¿Crees que deberías tener más tiempo para investigar en este trabajo?  \
# 197                                                NaN
#
#     ¿Cuántas horas a la semana, en promedio, debería aumentar tu dedicación a la investigación?  \
# 197                                                NaN
#
#     ¿Crees que deberías tener más tiempo para enseñar en este trabajo?  \
# 197                                                NaN
#
#     ¿Cuántas horas a la semana, en promedio, debería aumentar tu dedicación a la docencia?  \
# 197                                                NaN
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [No he sufrido discriminación]  \
# 197                                                NaN
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación de género]  \
# 197                                                NaN
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por ser extranjero/a]  \
# 197                                                NaN
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por tener discapacidad]  \
# 197                                                NaN
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por tener hijos o hijas]  \
# 197                                                NaN
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por estar sobrecalificado]  \
# 197                                                NaN
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Otro]  \
# 197                                                NaN
#
#     Actualmente, ¿estás buscando trabajo?  \
# 197                                    Sí
#
#      ¿Hace cuántos meses estás buscando trabajo?  \
# 197                                          3.0
#
#     ¿Crees que seguirás desempeñando este trabajo remunerado en julio de 2018?  \
# 197                                                NaN
#
#     Finalmente, ¿cuál es tu opinión sobre el sistema de ciencia y tecnología en Chile, y sobre el proceso de inserción de científicos en Chile?  \
# 197  Por lo que he visto está un poco sesgado el pe...
#
#                                    ¿Cuál es tu género? ¿Cuál es tu edad?  \
# 197   o buscan técnicos que salen más económicos pa...          Femenino
#
#     ¿Cuál es tu nacionalidad? En caso de tener más de una nacionalidad, por favor escoge tu país de origen (donde naciste).  \
# 197                                                 26
#
#     Durante tu formación profesional, ¿ha sido uno de tus anhelos trabajar en el ámbito académico?  \
# 197                                              Chile
#
#     Tiempo total  Tiempo del grupo: Sección 1: Preguntas iniciales  \
# 197           No                                            526.06
#
#      Tiempo del grupo: Sección 2: Sobre situación académica  \
# 197                                              10.48
#
#      Tiempo del grupo: Sección 3: Sobre la realización de postdoctorados  \
# 197                                              59.66
#
#      Tiempo del grupo: Sección 4: Sobre reinserción en Chile  \
# 197                                                NaN
#
#      Tiempo del grupo: Sección 5: Sobre situación laboral  \
# 197                                                NaN
#
#      Tiempo del grupo: Sección 6: Preguntas finales  Unnamed: 131
# 197                                           28.76        427.16

# %% [markdown]
# - Corregimos la respuesta abierta del ID 334.
#
# Aquí el error ocurre en el campo 'Finalmente, ¿cuál es tu opinión sobre el sistema de ciencia y tecnología en Chile, y sobre el proceso de inserción de científicos en Chile?', donde la persona responde usando coma y el sistema separa la respuesta en dos campos. Agregamos doble comillas

# %%
encuesta_full_df[encuesta_full_df['¿Cuál es tu género?']=='Creo que es muy deficiente. Faltan mecanismos para integrarse, recursos para financiar las iniciativas de inserción estatales y fomentar la participción del mundo privado. Quizás se pueda fomentar el uso de un fondo tipo Ley Valdés de donaciones, para que las empresas financien distintos tipos de investigación. ']
# Out:
#      ID de la respuesta  Fecha en que inició Fecha de la ultima accion  \
# 303                 477  2018-01-25 22:27:41       2018-01-25 22:38:21
#
#     ¿Cuál es el grado académico más alto que has obtenido?  \
# 303                                    Doctorado (PhD)
#
#     ¿En qué disciplina y área clasificarías tu pregrado?  \
# 303                 Humanidades:Historia y Arqueología
#
#     ¿En qué disciplina y área clasificarías tu pregrado? [Otro]  \
# 303                                                NaN
#
#     ¿En qué año obtuviste tu pregrado?  \
# 303                               2005
#
#     ¿En qué disciplina y área clasificarías tu {postgrado}?  \
# 303                 Humanidades:Historia y Arqueología
#
#     ¿En qué disciplina y área clasificarías tu {postgrado}? [Otro]  \
# 303                                                NaN
#
#     ¿En qué año obtuviste tu {postgrado}?  \
# 303                                  2016
#
#     ¿En qué lugar realizaste tu {postgrado}?  \
# 303                Estados Unidos de América
#
#      En total, ¿cuántos artículos revisados por pares (peer-reviewed) has publicado en los últimos 5 años?  \
# 303                                                  2
#
#     ¿Cómo financiaste tus estudios de {postgrado}? [Fondos personales (e.g., ahorros, aporte familiar, etc.)]  \
# 303                                                 No
#
#     ¿Cómo financiaste tus estudios de {postgrado}? [Trabajo durante el estudio (e.g., pasantías, ayudantías, etc.)]  \
# 303                                                 No
#
#     ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales nacionales (e.g., becas Conicyt, Becas Chile, premios, etc.)]  \
# 303                                                 Sí
#
#     ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales extranjeros (e.g., becas o premios de universidad de estudios)]  \
# 303                                                 Sí
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en mi área de estudio]  \
# 303                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en otra área de estudio]  \
# 303                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Pasantía(s) en otros lugares de estudio o centros de investigación]  \
# 303                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo en mi lugar de estudio, sin relación con mis estudios]  \
# 303                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo fuera de mi lugar de estudio]  \
# 303                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo remoto de cualquier tipo]  \
# 303                                                NaN
#
#     ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Otro]  \
# 303                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)]  \
# 303                                                 Sí
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario]  \
# 303                                         Beca Chile
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)]  \
# 303                                                 No
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].1  \
# 303                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)]  \
# 303                                                 No
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].2  \
# 303                                                NaN
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)]  \
# 303                                                 No
#
#     ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].3  \
# 303                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)]  \
# 303                                                 Sí
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario]  \
# 303                                     Mosse Exchange
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)]  \
# 303                                   Mosse Fellowship
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].1  \
# 303                                                 No
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)]  \
# 303                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].2  \
# 303                                                 No
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)]  \
# 303                                                NaN
#
#     ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].3  \
# 303                                                 No
#
#     ¿Estás realizando o has realizado algún postdoctorado?  \
# 303                                                NaN
#
#     ¿En qué disciplina y área clasificarías tu postdoctorado?  \
# 303                                                 No
#
#     ¿En qué disciplina y área clasificarías tu postdoctorado? [Otro]  \
# 303                                                NaN
#
#     ¿En qué año terminaste tu postdoctorado? Si actuamente estás haciendo un postdoctorado, por favor responde "Estoy haciendo un postdoctorado ahora".  \
# 303                                                NaN
#
#     ¿En qué lugar realizaste (o estás realizando) tu postdoctorado?  \
# 303                                                NaN
#
#     ¿Has terminado más de un postdoctorado?  \
# 303                                     NaN
#
#     ¿Cuántos postdoctorados has realizado? ¿Estás en Chile ahora?  \
# 303                                    NaN                    NaN
#
#     ¿Tuviste que renunciar a algún trabajo u oportunidad académica por volver a Chile?  \
# 303            Sí, estoy en Chile de manera definitiva
#
#     Por favor describe brevemente el trabajo u oportunidad académica que perdiste por volver a Chile:  \
# 303                                                 No
#
#     ¿Hace cuánto tiempo volviste a Chile?  \
# 303                                   NaN
#
#     Luego de volver a Chile, ¿cuánto tiempo te tomó encontrar tu primer trabajo?  \
# 303                                   Entre 1 y 2 años
#
#     ¿Qué tan relacionado estaba ese trabajo con tu especialización en el {postgrado}?  \
# 303                                Entre 13 y 18 meses
#
#     En general, ¿cómo calificarías tu experiencia de reinserción en Chile?  \
# 303                       4 (Medianamente relacionado)
#
#     ¿Por qué razón(es) no volverás a Chile? [Porque nunca encontré trabajo relacionado con mis estudios]  \
# 303                                       1 (muy mala)
#
#     ¿Por qué razón(es) no volverás a Chile? [Porque en Chile no pude desarrollar mi área de investigación]  \
# 303                                                NaN
#
#     ¿Por qué razón(es) no volverás a Chile? [Porque recibí una muy buena oferta de trabajo en el extranjero]  \
# 303                                                NaN
#
#     ¿Por qué razón(es) no volverás a Chile? [Por motivos personales/familiares]  \
# 303                                                NaN
#
#     ¿Por qué razón(es) no volverás a Chile? [Otro]  \
# 303                                            NaN
#
#     ¿Por qué razón tienes que volver a Chile? [Porque firmé un pagaré que me obliga a volver]  \
# 303                                                NaN
#
#     ¿Por qué razón tienes que volver a Chile? [Porque tengo un acuerdo con mi empleador]  \
# 303                                                NaN
#
#     ¿Por qué razón tienes que volver a Chile? [Otro]  \
# 303                                              NaN
#
#     ¿Tu trabajo o búsqueda de trabajo está centrado en el el ámbito de la investigación científica?  \
# 303                                                NaN
#
#     Actualmente, ¿tienes trabajo remunerado en Chile?  \
# 303                                                Sí
#
#     ¿Cuántos trabajos posees actualmente?  \
# 303                                    Sí
#
#      {if(G5Q00003.NAOK=="1", "", "Para las preguntas siguientes, considera sólo el trabajo al que dedicas mayor cantidad de tiempo.")}  ¿Cuántas horas a la semana, en promedio, dedicas a este trabajo?  \
# 303                                                2.0
#
#     ¿En qué institución o área realizas tu trabajo?  \
# 303                                               6
#
#     ¿En qué institución o área realizas tu trabajo? [Otro]  \
# 303                                Universidad Privada
#
#     ¿A qué sector económico pertenece este trabajo?  \
# 303                                             NaN
#
#     ¿A qué sector económico pertenece este trabajo? [Otro]  \
# 303                       Sector Cuaternario:Educación
#
#     ¿En qué región de Chile realizas este trabajo?  \
# 303                                            NaN
#
#     ¿Qué tan relacionado está tu trabajo con tu especialización en el {postgrado}?  \
# 303                     XIII Metropolitana de Santiago
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu salario]  \
# 303                       4 (Medianamente relacionado)
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Los beneficios que te ofrece el trabajo]  \
# 303                               1 (Muy insatisfecho)
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu estabilidad laboral]  \
# 303                               1 (Muy insatisfecho)
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [La localización del trabajo]  \
# 303                               1 (Muy insatisfecho)
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Las condiciones generales de trabajo]  \
# 303                  4 (Ni satisfecho ni insatisfecho)
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [La posibilidad de progreso]  \
# 303                  4 (Ni satisfecho ni insatisfecho)
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [El reto intelectual que supone el trabajo]  \
# 303                                                  2
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [El nivel de responsabilidad que tienes en el trabajo]  \
# 303                                                  2
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu grado de independencia en el trabajo]  \
# 303                  4 (Ni satisfecho ni insatisfecho)
#
#     Respecto de tu trabajo, ¿qué tan satisfecho estás con...? [Tu contribución a la sociedad a través del trabajo]  \
# 303                  4 (Ni satisfecho ni insatisfecho)
#
#     ¿Qué tan necesario es tener un {postgrado} para realizar este trabajo?  \
# 303                                                  2
#
#     ¿En qué grado este trabajo pone en riesgo tu...? [Integridad Física]  \
# 303                                         4 (Neutro)
#
#     ¿En qué grado este trabajo pone en riesgo tu...? [Integridad Psicológica]  \
# 303                                 1 (Nada de riesgo)
#
#     ¿En qué grado este trabajo pone en riesgo tu...? [Salud en general]  \
# 303                                 1 (Nada de riesgo)
#
#     ¿En qué grado este trabajo pone en riesgo tu...? [Seguridad personal o familiar]  \
# 303                                 1 (Nada de riesgo)
#
#     ¿Cuentas con un seguro o previsión de salud?  \
# 303                           1 (Nada de riesgo)
#
#     ¿En qué grado tu seguro o previsión de salud cubre los riesgos que implica tu trabajo?  \
# 303                                                 Sí
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Académico/docencia]  \
# 303                 4 (Cubre parcialmente los riesgos)
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Administrativo/Gestión]  \
# 303                                                 Sí
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Asistente de investigación]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Consultoría]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Director de proyectos]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Docencia (ayudantía)]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Edición de textos/publicaciones]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador asociado]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador colaborador en proyectos de terceros]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Investigador principal]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Trabajo de campo /producción de información o datos para investigación / trabajo de escritorio.]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Traducciones]  \
# 303                                                 No
#
#     ¿Qué tipo de actividades desempeñas en este trabajo? [Otro]  \
# 303                                                 No
#
#     ¿Qué tipo de relación laboral tienes en este trabajo?  \
# 303                                                NaN
#
#     ¿Qué tipo de relación laboral tienes en este trabajo? [Otro]  \
# 303             A honorarios ("Boletear sin contrato")
#
#     Considerando todos tus ingresos, ¿en que rango sitúas tu ingreso líquido mensual total?  \
# 303                                                NaN
#
#     ¿Qué tan satisfecho estás con tu nivel de ingresos total mensual?  \
# 303                                   Menos de 400.000
#
#     ¿Crees que deberías tener más tiempo para investigar en este trabajo?  \
# 303                     1 (Completamente insatisfecho)
#
#     ¿Cuántas horas a la semana, en promedio, debería aumentar tu dedicación a la investigación?  \
# 303                                                 Sí
#
#     ¿Crees que deberías tener más tiempo para enseñar en este trabajo?  \
# 303                                                 15
#
#     ¿Cuántas horas a la semana, en promedio, debería aumentar tu dedicación a la docencia?  \
# 303                                                 No
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [No he sufrido discriminación]  \
# 303                                                NaN
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación de género]  \
# 303                                                 No
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por ser extranjero/a]  \
# 303                                                 Sí
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por tener discapacidad]  \
# 303                                                 No
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por tener hijos o hijas]  \
# 303                                                 No
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Sí, discriminación por estar sobrecalificado]  \
# 303                                                 Sí
#
#     ¿Has sufrido algún tipo de discriminación en tu(s) trabajo(s) como científico o científica? [Otro]  \
# 303                                                 No
#
#     Actualmente, ¿estás buscando trabajo?  \
# 303             Por ser minoria religiosa
#
#      ¿Hace cuántos meses estás buscando trabajo?  \
# 303                                          NaN
#
#     ¿Crees que seguirás desempeñando este trabajo remunerado en julio de 2018?  \
# 303                                                NaN
#
#     Finalmente, ¿cuál es tu opinión sobre el sistema de ciencia y tecnología en Chile, y sobre el proceso de inserción de científicos en Chile?  \
# 303                                                 Sí
#
#                                    ¿Cuál es tu género? ¿Cuál es tu edad?  \
# 303  Creo que es muy deficiente. Faltan mecanismos ...          Femenino
#
#     ¿Cuál es tu nacionalidad? En caso de tener más de una nacionalidad, por favor escoge tu país de origen (donde naciste).  \
# 303                                                 35
#
#     Durante tu formación profesional, ¿ha sido uno de tus anhelos trabajar en el ámbito académico?  \
# 303                                              Chile
#
#     Tiempo total  Tiempo del grupo: Sección 1: Preguntas iniciales  \
# 303           Sí                                            640.41
#
#      Tiempo del grupo: Sección 2: Sobre situación académica  \
# 303                                              20.69
#
#      Tiempo del grupo: Sección 3: Sobre la realización de postdoctorados  \
# 303                                              85.07
#
#      Tiempo del grupo: Sección 4: Sobre reinserción en Chile  \
# 303                                              14.07
#
#      Tiempo del grupo: Sección 5: Sobre situación laboral  \
# 303                                              34.85
#
#      Tiempo del grupo: Sección 6: Preguntas finales  Unnamed: 131
# 303                                          372.12        113.61

# %% [markdown]
# - La respuesta del registro 477 parece bien, imprimiré en pantalla la respuesta detallada
#
# Este error es más sútil, pues en el campo '¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario]' la persona respondió dos frases y las separó por coma, lamentablemente el sistema las separó en dos columnas. Arreglamos el csv agregando doblo comilla.

# %%
encuesta_full_df[encuesta_full_df['¿Cuál es tu género?']==' con contrato y no con boleta.']
# Out:
# Empty DataFrame
# Columns: [ID de la respuesta, Fecha en que inició, Fecha de la ultima accion, ¿Cuál es el grado académico más alto que has obtenido?, ¿En qué disciplina y área clasificarías tu pregrado?, ¿En qué disciplina y área clasificarías tu pregrado? [Otro], ¿En qué año obtuviste tu pregrado?, ¿En qué disciplina y área clasificarías tu {postgrado}?, ¿En qué disciplina y área clasificarías tu {postgrado}? [Otro], ¿En qué año obtuviste tu {postgrado}?, ¿En qué lugar realizaste tu {postgrado}?, En total, ¿cuántos artículos revisados por pares (peer-reviewed) has publicado en los últimos 5 años?, ¿Cómo financiaste tus estudios de {postgrado}? [Fondos personales (e.g., ahorros, aporte familiar, etc.)], ¿Cómo financiaste tus estudios de {postgrado}? [Trabajo durante el estudio (e.g., pasantías, ayudantías, etc.)], ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales nacionales (e.g., becas Conicyt, Becas Chile, premios, etc.)], ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales extranjeros (e.g., becas o premios de universidad de estudios)], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en mi área de estudio], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en otra área de estudio], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Pasantía(s) en otros lugares de estudio o centros de investigación], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo en mi lugar de estudio, sin relación con mis estudios], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo fuera de mi lugar de estudio], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo remoto de cualquier tipo], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Otro], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].1, ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].2, ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].3, ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].1, ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].2, ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].3, ¿Estás realizando o has realizado algún postdoctorado?, ¿En qué disciplina y área clasificarías tu postdoctorado?, ¿En qué disciplina y área clasificarías tu postdoctorado? [Otro], ¿En qué año terminaste tu postdoctorado? Si actuamente estás haciendo un postdoctorado, por favor responde "Estoy haciendo un postdoctorado ahora"., ¿En qué lugar realizaste (o estás realizando) tu postdoctorado?, ¿Has terminado más de un postdoctorado?, ¿Cuántos postdoctorados has realizado?, ¿Estás en Chile ahora?, ¿Tuviste que renunciar a algún trabajo u ...
# Index: []

# %% [markdown]
# - Corregimos la respuesta abierta del ID 849.
#
# Aquí el error ocurre en el campo 'Finalmente, ¿cuál es tu opinión sobre el sistema de ciencia y tecnología en Chile, y sobre el proceso de inserción de científicos en Chile?', donde la persona responde usando coma y el sistema separa la respuesta en dos campos. Agregamos doble comillas

# %%
encuesta_full_df[encuesta_full_df['¿Cuál es tu género?'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID de la respuesta, Fecha en que inició, Fecha de la ultima accion, ¿Cuál es el grado académico más alto que has obtenido?, ¿En qué disciplina y área clasificarías tu pregrado?, ¿En qué disciplina y área clasificarías tu pregrado? [Otro], ¿En qué año obtuviste tu pregrado?, ¿En qué disciplina y área clasificarías tu {postgrado}?, ¿En qué disciplina y área clasificarías tu {postgrado}? [Otro], ¿En qué año obtuviste tu {postgrado}?, ¿En qué lugar realizaste tu {postgrado}?, En total, ¿cuántos artículos revisados por pares (peer-reviewed) has publicado en los últimos 5 años?, ¿Cómo financiaste tus estudios de {postgrado}? [Fondos personales (e.g., ahorros, aporte familiar, etc.)], ¿Cómo financiaste tus estudios de {postgrado}? [Trabajo durante el estudio (e.g., pasantías, ayudantías, etc.)], ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales nacionales (e.g., becas Conicyt, Becas Chile, premios, etc.)], ¿Cómo financiaste tus estudios de {postgrado}? [Fondos no personales extranjeros (e.g., becas o premios de universidad de estudios)], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en mi área de estudio], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Ayudantía(s) en otra área de estudio], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Pasantía(s) en otros lugares de estudio o centros de investigación], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo en mi lugar de estudio, sin relación con mis estudios], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo fuera de mi lugar de estudio], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Trabajo remoto de cualquier tipo], ¿Qué tipo de trabajo desempeñaste para financiar tus estudios? [Otro], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].1, ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].2, ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)], ¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario].3, ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Beca o premio (por favor indica el nombre de la beca o premio)], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Crédito de un banco (por favor indica el nombre del banco)], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].1, ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Financiamiento de empleador (por favor indica el nombre del empleador)], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].2, ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Otro tipo de fondos (por favor indica qué tipo)], ¿Con qué tipo de fondos extranjeros financiaste tu {postgrado}? [Comentario].3, ¿Estás realizando o has realizado algún postdoctorado?, ¿En qué disciplina y área clasificarías tu postdoctorado?, ¿En qué disciplina y área clasificarías tu postdoctorado? [Otro], ¿En qué año terminaste tu postdoctorado? Si actuamente estás haciendo un postdoctorado, por favor responde "Estoy haciendo un postdoctorado ahora"., ¿En qué lugar realizaste (o estás realizando) tu postdoctorado?, ¿Has terminado más de un postdoctorado?, ¿Cuántos postdoctorados has realizado?, ¿Estás en Chile ahora?, ¿Tuviste que renunciar a algún trabajo u ...
# Index: []

# %% [markdown]
# - Corregimos la respuesta abierta del ID 817.
#
# Este error es más sútil, pues en el campo '¿Con qué tipo de fondos nacionales financiaste tu {postgrado}? [Comentario]' la persona respondió dos frases y las separó por coma, lamentablemente el sistema las separó en dos columnas. Arreglamos el csv agregando doble comilla.
